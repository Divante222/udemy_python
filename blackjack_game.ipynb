# %%
import random
import time

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}

# %%
class  Card():
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck():
    
    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                #create the card object
                
                created_card = Card(suit,rank)
                self.all_cards.append(created_card)
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %%
class Player():
    def __init__(self, name):
        self.name = name
        self.all_cards = []
        self.money = 100
        
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    
    def add_cards(self, new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
            
            
    def new_hand(self):
        self.all_cards = []
    
    
    def __str__(self):
        return f"player {self.name} has {len(self.all_cards)} cards"

# %%
game_over = False


new_player = Player('Divante')
dealer = Player('dealer')

new_game = True
    
while new_game == True:
    
    new_deck = Deck()
    new_deck.shuffle()
    new_player.add_cards(new_deck.deal_one())
    new_player.add_cards(new_deck.deal_one())
    
    
    dealer.add_cards(new_deck.deal_one())
    dealer.add_cards(new_deck.deal_one())
    
    cards_list = []

    
    while True:
        current_hand = False

        if new_player.money > 0:
            try:
                
                print(f'Amount of money {new_player.money}')
                bet = int(input('How much do you want to bet: '))
                
                if new_player.money >= bet:
                        new_player.money -= bet
                        print(f"Money remaining: {new_player.money}\n")
                        current_hand = True
                        break
                else:
                    raise Exception("Sorry insufficient funds")
            except:
                print('please enter a proper number')
        else:
            print('You lose!')
            new_game = False
            break

            

            
    while current_hand == True:
        total = 0
        
        card_list = []
        cards_list_aces = []
        
        
        
        
        for card in new_player.all_cards:
            if 'Ace' in str(card):
                cards_list_aces.append(str(card))
                print(card)
            else:
                card_list.append(str(card))

                total += card.value
                    
        
                    
                    
        for num in range(len(cards_list_aces)):
            
            if len(cards_list_aces) == 4:
                if total == 7:
                    total = 21
                    
                elif total < 9:
                    total += 14    
                    
                else:
                    total += 4
                    
                    
            if len(cards_list_aces) == 3:
                if total == 8:
                    total = 21
                    
                elif total < 8:
                    total += 13
                else:
                    total += 3
                    
                    
            if len(cards_list_aces) == 2:
                if total == 9:
                    total = 21
                    
                elif total <9:
                    total += 12
                    
                else:
                    total += 4
                    
                
            if total + (len(cards_list_aces) * 11) > 21:
                total += 1
            else:
                total += 11
                    
                    
            
        print(card_list + cards_list_aces)


        print(f"your hand total:{total}")
        print()

 
        print(f"Dealers showing {str(dealer.all_cards[0])}\nvalue: {dealer.all_cards[0].value}")
        
        if total < 22:
            
            choice = input('1 for hit\n2 for stand: ')
            print('\n')
            if choice == '1':
                new_player.add_cards(new_deck.deal_one())
                print(new_player.all_cards[-1])
            elif choice == '2':
                
                
                while True:           
                    dealer_total = 0

                    dealer_card_list = []
                    dealer_cards_list_aces = []

                    for card in dealer.all_cards:
                        if 'Ace' in str(card):
                            dealer_cards_list_aces.append(str(card))
                            print(card)
                        else:
                            dealer_card_list.append(str(card))

                            dealer_total += card.value

                            
                    for num in range(len(dealer_cards_list_aces)):

                        if len(dealer_cards_list_aces) == 4:
                            if dealer_total == 7:
                                dealer_total = 21

                            elif dealer_total < 9:
                                dealer_total += 14    

                            else:
                                dealer_total += 4


                        if len(dealer_cards_list_aces) == 3:
                            if dealer_total == 8:
                                dealer_total = 21

                            elif dealer_total < 8:
                                dealer_total += 13
                            else:
                                dealer_total += 3


                        if len(dealer_cards_list_aces) == 2:
                            if dealer_total == 9:
                                dealer_total = 21

                            elif dealer_total <9:
                                dealer_total += 12

                            else:
                                dealer_total += 4


                        if dealer_total + (len(dealer_cards_list_aces) * 11) > 21:
                            dealer_total += 1
                        else:
                            dealer_total += 11




                            
                            
                            
                            
                            
                            
                    print(f"Dealers cards: {dealer_card_list}")
                    print(f"Dealer total: {dealer_total}")
                    print()
                    choice = ''

                    print('\n' * 3)
                    
                    if dealer_total > 21:
                        print('You win dealer bust')
                        new_player.money = new_player.money + (bet*2)
                        current_hand = False
                        new_player.new_hand()
                        dealer.new_hand()
                        break
                        
                    elif dealer_total < total:
                        dealer.add_cards(new_deck.deal_one())
                        print('drew a card')
                        time.sleep(3)
                        
                    elif dealer_total == 21 and total == 21:
                        print('Tie')
                        new_player.money = new_player.money + bet
                        current_hand = False
                        new_player.new_hand()
                        dealer.new_hand()
                        break
                        
                    elif dealer_total > total:
                        print('you lose')
                        current_hand = False
                        new_player.new_hand()
                        dealer.new_hand()
                        break
                    elif dealer_total == total:
                        print('Tie')
                        new_player.money = new_player.money + bet
                        current_hand = False
                        new_player.new_hand()
                        dealer.new_hand()
                        break
                    else:
                        print('something broke')
                        input('')
                                   
            else:
                print('improper selection')
            
        else:
            print('Bust')
            choice = ''
            current_hand = False
            new_player.new_hand()
            dealer.new_hand()
            print('\n' * 3)
# Out:
# Amount of money 100
# How much do you want to bet: 50
# Money remaining: 50
#
# ['Four of Diamonds', 'Ten of Hearts']
# your hand total:14
#
# Dealers showing King of Hearts
# value: 10
# 1 for hit
# 2 for stand: 1
#
#
# Queen of Hearts
# ['Four of Diamonds', 'Ten of Hearts', 'Queen of Hearts']
# your hand total:24
#
# Dealers showing King of Hearts
# value: 10
# Bust
#
#
#
#
# Amount of money 50
# How much do you want to bet: 20
# Money remaining: 30
#
# ['Two of Diamonds', 'King of Spades']
# your hand total:12
#
# Dealers showing Six of Spades
# value: 6
# 1 for hit
# 2 for stand: 1
#
#
# Four of Clubs
# ['Two of Diamonds', 'King of Spades', 'Four of Clubs']
# your hand total:16
#
# Dealers showing Six of Spades
# value: 6
# 1 for hit
# 2 for stand: 2
#
#
# Dealers cards: ['Six of Spades', 'Seven of Hearts']
# Dealer total: 13
#
#
#
#
#
# drew a card
# Dealers cards: ['Six of Spades', 'Seven of Hearts', 'Six of Hearts']
# Dealer total: 19
#
#
#
#
#
# you lose
# Amount of money 30
# ...
